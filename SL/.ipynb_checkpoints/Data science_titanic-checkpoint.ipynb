# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
titanic_df=pd.read_csv('train.csv')
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Converting survived columns to strings
titanic_df["Survived"]=titanic_df['Survived'].map({0:"Died",1:"Survived"})
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1      Died       3
# 1            2  Survived       1
# 2            3  Survived       3
# 3            4  Survived       1
# 4            5      Died       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print("Data transformation after dropping columns")
titanic_df.drop(['Parch','Name','Ticket','PassengerId'],axis=1,inplace=True) #First way of dropping columns
titanic_df.head()
# Out:
# Data transformation after dropping columns
#    Survived  Pclass     Sex   Age  SibSp     Fare Cabin Embarked
# 0      Died       3    male  22.0      1   7.2500   NaN        S
# 1  Survived       1  female  38.0      1  71.2833   C85        C
# 2  Survived       3  female  26.0      0   7.9250   NaN        S
# 3  Survived       1  female  35.0      1  53.1000  C123        S
# 4      Died       3    male  35.0      0   8.0500   NaN        S

# %%
titanic_df=titanic_df.drop(['SibSp','Fare'],axis=1)  #Second way of dropping columns
titanic_df.head()
# Out:
#    Survived  Pclass     Sex   Age Cabin Embarked
# 0      Died       3    male  22.0   NaN        S
# 1  Survived       1  female  38.0   C85        C
# 2  Survived       3  female  26.0   NaN        S
# 3  Survived       1  female  35.0  C123        S
# 4      Died       3    male  35.0   NaN        S

# %%
titanic_df['Pclass']=titanic_df['Pclass'].map({1:'Luxury Class',2:'Economy Class',3:'Lower Class'})
titanic_df.head()
# Out:
#    Survived        Pclass     Sex   Age Cabin Embarked
# 0      Died   Lower Class    male  22.0   NaN        S
# 1  Survived  Luxury Class  female  38.0   C85        C
# 2  Survived   Lower Class  female  26.0   NaN        S
# 3  Survived  Luxury Class  female  35.0  C123        S
# 4      Died   Lower Class    male  35.0   NaN        S

# %%
titanic_df['Embarked']=titanic_df['Embarked'].fillna("S")
# print(titanic_df.head())
titanic_df.head()
# Out:
#    Survived        Pclass     Sex   Age Cabin Embarked
# 0      Died   Lower Class    male  22.0   NaN        S
# 1  Survived  Luxury Class  female  38.0   C85        C
# 2  Survived   Lower Class  female  26.0   NaN        S
# 3  Survived  Luxury Class  female  35.0  C123        S
# 4      Died   Lower Class    male  35.0   NaN        S

# %%
titanic_df['Embarked']=titanic_df['Embarked'].map({'C':'Cherbourg','S':'Southampton','Q':'Queenstown'})
titanic_df.head()
# Out:
#    Survived        Pclass     Sex   Age Cabin     Embarked
# 0      Died   Lower Class    male  22.0   NaN  Southampton
# 1  Survived  Luxury Class  female  38.0   C85    Cherbourg
# 2  Survived   Lower Class  female  26.0   NaN  Southampton
# 3  Survived  Luxury Class  female  35.0  C123  Southampton
# 4      Died   Lower Class    male  35.0   NaN  Southampton

# %%
print('Data Visualizations')
print('1.Visualizing Survival rate based on Passenger Sitting class')
ax=sns.countplot(x='Pclass',hue='Survived',data=titanic_df,palette='Set1')
ax.set(xlabel="Passenger classes",ylabel="Survival rate",title="Survival rate VS Passenger sitting class")
plt.show()
# Out:
# Data Visualizations
# 1.Visualizing Survival rate based on Passenger Sitting class

# %%
print('2.Visualizing Survival rate based on Gender')
ax=sns.countplot(x='Sex',hue='Survived',data=titanic_df,palette='Set2')
ax.set(xlabel="Gender",ylabel="Survival rate",title="Survival rate VS Gender")
plt.show()
# Out:
# 2.Visualizing Survival rate based on Gender

# %%
titanic_df
# Out:
#      Survived         Pclass     Sex   Age Cabin     Embarked
# 0        Died    Lower Class    male  22.0   NaN  Southampton
# 1    Survived   Luxury Class  female  38.0   C85    Cherbourg
# 2    Survived    Lower Class  female  26.0   NaN  Southampton
# 3    Survived   Luxury Class  female  35.0  C123  Southampton
# 4        Died    Lower Class    male  35.0   NaN  Southampton
# ..        ...            ...     ...   ...   ...          ...
# 886      Died  Economy Class    male  27.0   NaN  Southampton
# 887  Survived   Luxury Class  female  19.0   B42  Southampton
# 888      Died    Lower Class  female   NaN   NaN  Southampton
# 889  Survived   Luxury Class    male  26.0  C148    Cherbourg
# 890      Died    Lower Class    male  32.0   NaN   Queenstown
#
# [891 rows x 6 columns]

# %%
print('3.Visualizing Survival rate based on Passenger Age group')
titanic_df['Age']=titanic_df['Age'].fillna(20)
interval=(0,18,35,60,120)
categories=['Children','Teens','Adult','Old']
titanic_df['Age_cats']=pd.cut(titanic_df.Age,interval,labels=categories)
ax=sns.countplot(x='Age_cats',hue='Survived',data=titanic_df,palette='Set3')
ax.set(xlabel="Age groups",ylabel="Survival rate",title="Survival rate VS Age groups")
plt.show()
# Out:
# 3.Visualizing Survival rate based on Passenger Age group

# %%
titanic_df.head()
# Out:
#    Survived        Pclass     Sex   Age Cabin     Embarked Age_cats
# 0      Died   Lower Class    male  22.0   NaN  Southampton    Teens
# 1  Survived  Luxury Class  female  38.0   C85    Cherbourg    Adult
# 2  Survived   Lower Class  female  26.0   NaN  Southampton    Teens
# 3  Survived  Luxury Class  female  35.0  C123  Southampton    Teens
# 4      Died   Lower Class    male  35.0   NaN  Southampton    Teens

# %%
print('3.Visualizing Survival rate based on Embarking port')
ax=sns.countplot(x='Embarked',hue='Survived',data=titanic_df,palette='Set1')
ax.set(xlabel="Ports",ylabel="Survival rate",title="Survival rate VS Embarking ports")
plt.show()
# Out:
# 3.Visualizing Survival rate based on Embarking port
